# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("datasets/2023_global_country_development_and_prosperity_index/data.csv")

# %%
# Assuming the country column is named "Country"
country_column = "Country"  # Adjust this if the column name is different

# Remove leading and trailing spaces from country names
df[country_column] = df[country_column].str.strip()

# Set the country column as the index
df.set_index(country_column, inplace=True)

categories = ['AveragScore', 'EconomicQuality', 'LivingConditions', 'Health', 'Education']

brazil = []
slovenia = []
china = []
united_states = []

for category in categories:
    brazil.append(df.loc["Brazil"][category])
    slovenia.append(df.loc["Slovenia"][category])
    china.append(df.loc["China"][category])
    united_states.append(df.loc["United States"][category])

brazil.append(brazil[0])

slovenia.append(slovenia[0])

china.append(china[0])

united_states.append(united_states[0])

categories.append(categories[0])
label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(categories))

ax = plt.subplot(polar=True)

# Plot each country's data
ax.plot(label_loc, brazil, label='Brazil', linewidth=2)
ax.fill(label_loc, brazil, alpha=0.25)
ax.plot(label_loc, slovenia, label='Slovenia', linewidth=2)
ax.fill(label_loc, slovenia, alpha=0.25)
ax.plot(label_loc, china, label='China', linewidth=2)
ax.fill(label_loc, china, alpha=0.25)
ax.plot(label_loc, united_states, label='United States', linewidth=2)
ax.fill(label_loc, united_states, alpha=0.25)

# Title and labels
plt.title('Countries Comparison', size=20, color='black', y=1.1)
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories, fontsize=12)

# Improve readability
plt.legend(loc='lower right', bbox_to_anchor=(1.25, -0.1))

# %%
df
# Out:
#                        Country  AveragScore  SafetySecurity  PersonelFreedom  \
# 0                      Denmark        84.55           92.59            94.09
# 1                       Sweden        83.67           90.97            91.90
# 2                       Norway        83.59           93.30            94.10
# 3                      Finland        83.47           89.56            91.96
# 4                  Switzerland        83.42           95.66            87.50
# ..                         ...          ...             ...              ...
# 162                    Somalia        34.39           31.91            34.32
# 163                Afghanistan        34.18           20.93            31.02
# 164   Central African Republic        32.83           35.30            36.83
# 165                      Yemen        32.65           22.60            25.30
# 166                South Sudan        30.40           16.54            26.98
#
# ...

# %%
# Top 25 countries with the best health index. 
df_top_5_best_health = df[['Country', 'Health']].sort_values('Health', ascending=False).head(25)
top_5_best_health_graph = px.bar(df_top_5_best_health, x='Country', y='Health', color='Country', labels={'Health': 'Health index'})
top_5_best_health_graph.show()

# %%
# Top 25 countries with the best education index. 
df_top_5_best_education = df[['Country', 'Education']].sort_values('Education', ascending=False).head(25)
top_5_best_education_graph = px.bar(df_top_5_best_education, x='Country', y='Education', color='Country', labels={'Education': 'Education index'})
top_5_best_education_graph.show()
